# %% [markdown]
# <a href="https://colab.research.google.com/github/F-Yousefi/Maths-ML/blob/main/TaylorSeries.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ***
# $\mathbf{\text{Getting a handle on Taylor Series}}$<br>
# ***
# #### **Preface:**
# * Welcome to the first module of the course which is based on the most tricky concepts of mathematics that are quite essential in the area of machine learning and deep learning including Taylor Series, Newton method, gradient descent constrained optimization, linear regression, and logistic regression.
#
# * Through this course, it is supposed that you are already familiar with some of the basic concepts of multivariate calculus such as derivatives, differentiating, Jacobian, gradient, and Hessian. If you've not had any acquaintance with the mentioned concepts, don't panic. Fortunately, there are a bunch of really good resources in this area throughout the internet. Additionally, there are some useful links at the end of the file "README.md" which help you easily find what you need to acquire a comprehensive understanding of this module.
#
# #### **What makes Taylor Series special?:**
# * Taylor Series enables us to approximately re-express a complex function using a series of simpler functions; this was the short answer, however, if you are looking for the complete answer, I assure you that you are in the right place.
# At the end of this module, you can apply this amazing approach to any problem, not only by hand in your notebook but also by programming in a notebook like this one.<br><br>
#
# * Consider the function $f(x)= cos(x)$. If trigonometry makes you feel uneasy or unwelcome to explore, I have to confess that you are not alone at all. I'm going to introduce you to our savior, Taylor Series whose superhero power is to disappear the cosine function $cos(θ)$ and turn it into a quadratic expression of the form $(ax^2 +bx+c)$ which doesn't even contain any reference to trigonometry.<br><br>
#
# * In fact, it is used to build an approximation to any complex function using simpler functions. It is composed of a sequence of gradually improving approximations. It just needs to know EVERYTHING about a specific point in the complex function, and by everything I mean the function's value, Jacobian, Hessian ... at the point. Let's see it through an example to build up your intuition so that you can understand this concept geometrically.
# <br>
#
# $(0.1)$
# $$ zero_{-} degree_{-} polynomial : f_0(x) = c ,$$<br>
#
# ----
# $(0.2)$
# $$ first_{-} degree_{-} polynomial : f_1(x) = bx+c,$$<br>
# $$f_1(x) = f^J(x)x+f(x)$$
#
# ----
# $(0.3)$
# $$ second_{-} degree_{-} polynomial : f_2(x) = ax^2+bx+c,$$<br>
# $$f_2(x) = \frac{1}{2}f^H(x)x^2+f^J(x)x+c$$
# $$....$$
#
# * As you can see, the function of zero degree $(0.1)$ is just a straight horizontal line at the point x. $figure(1.1)$. It is a flat line and not even a function of x, because the only piece of information which is given to it is the function's value at the point x, as a result, the approximation is quite poor. We can give it the second piece of information which is the function's gradient at our point of interest x $(0.1)$. Now, our approximation is a straight line, this time with the same gradient as the complex function at the point.$figure(1.1)$ Notice that each term in the series provides a better approximation. The more information you give, the more accurate approximation you get.
# <br>
#
# * Let's consider $f(x) = cos(x)$ and apply our new approach to it.
# $$f_0(x) = f(0)  → f^0(x) = cos(x)  ,$$$$  f^0(x) = 1 $$
# * *First approximation is just a straight horizontal line at $f(x) = 1$ which is a poor approximation; however, there is still room to improve.*
# --------
# $$f_1(x) = f'(0)x+f(0) ,$$
# $$ f'(x) = -sin(x) → f'(0) = 0,$$
# $$f_1(x) = (0)x+ 1  $$$$ f_1(x) = 1 $$
# * *This term cannot make any improvement because in $x=0$ the gradient is zero.*
# ------
# $$f_2(x) = \frac{1}{2} f''(0)x^2+ f'(0)x+f(0) $$$$ f''(x) = -cos(x) → f''(0) = -1 $$
# $$f_2(x) = \frac{-1}{2} x^2 + 1 $$
#
# * *The second-degree polynomial which is a relatively good approximation. Notice that these zeros will occur whenever differentiate an odd number of times.*
# -----
# <br><br>
# * I hope you already have noticed the pattern. We can generalize this pattern to give us the polynomial expression of n degree without working through it as follows:
#
# $(0.4)$
# $$ f_n(x) =\sum \limits _{i=0} ^{n}\frac{(-1)^nx^{2n}}{2n!}$$ <br>
#
#
# $(0.5)$
# $$ f_n(x) =1 - \frac{x^2}{2}+\frac{x^4}{6} ....$$
# <br>
#
#
# * I have to confess that doesn't count as a Taylor Series, by the way. When we are specifically looking at point zero, this case is referred to as a Maclaruin Series. The generalized form of Maclaurin and Taylor series at the point $p$ are as follows:
#
#
#
#
#
# $(0.6)$
# $$ Maclaurin Series Formula : T =\sum \limits _{i=0} ^{n}\frac{f^n(0)}{n!} x^n  $$
# <br>
# $(0.7)$
# $$ Talor Series Formula : T =\sum \limits _{i=0} ^{n}\frac{f^n(p)}{n!} (x-p)^n  $$
# <br><br>
# * Using this series, you can easily build up an approximation to any complex function which is continuous everywhere and well-behaved. Let's now ask our computers to plot whatever we have learned here.

# %% [markdown]
# ***
# $\mathbf{\text{1. Figures: Taylor Series}}$<br>
# ***

# %%
# Importing required libraries
import numpy as np
import matplotlib.pyplot as plt
import math

# Taylor series definition {FIGURE 1.1}
#>>>>>>>>>>>>>>>>>>>>>>>>>
n = 1
ts= lambda x,n: sum(((-1)**i) * (x ** (2*i)) / (math.factorial(2 * i)) for i in range(n+1))
names = ["zero degree expression $f_0(x)$","second degree expression $f_2(x)$"]
#<<<<<<<<<<<<<<<<<<<<<<<<<


#Creating a vector of 100 various values of x
#between -20 and +20 to help us plot our function.
x = np.linspace(-20,+20,100)


for i in range(n+1): #Implementing Sigma (sum) function.

  #Plotting Configuration
  plt.rcParams['figure.figsize'] = [6.0, 3.0]
  plt.rcParams['figure.dpi'] = 80
  plt.plot(x,ts(x,i) , color = 'red')
  plt.plot(x,np.cos(x) , color = 'blue')
  plt.xlim((-6,6))
  plt.ylim((-3,3))
  plt.xlabel(names[i])
  plt.title("Figure 1.1")
  plt.grid(visible=True)
  plt.show()

# %% [markdown]
# ***
# $\mathbf{\text{2.Assessment one: Taylor Series}}$<br>
# ***
# ***In this this assessment you are asked to find the corresponding Taylor series for the following set of functions:***
#
# $(2.1)$
# $$f_{}(x) = cos_{}(x),$$ <br>
# $(2.2)$
# $$ f(x) = e^x,$$ <br>
# $(2.3)$
# $$ f(x,y) = e^{-(x^2+y^2)}.$$ <br>

# %% [markdown]
# $Practice (2.1):$<br>
# * As you saw above, the corresponding Maclaurin series for the cosine fuction was as follow:
# <br>
#
# $(0.4)$
# $$ f_n(x) =\sum \limits _{i=0} ^{n}\frac{(-1)^nx^{2n}}{2n!}$$ <br>
#
#
# $(0.5)$
# $$ f_n(x) =1 - \frac{x^2}{2}+\frac{x^4}{6} ....$$
# <br>
#
# * So Let's plot the approximate function up to $f_8(x)$:
#   * The red curve is showing the approximation.
#   * The bule one is showing the complex function.

# %%
# Importing required libraries
import numpy as np
import matplotlib.pyplot as plt
import math

# Maclaurin Series definition
#>>>>>>>>>>>>>>>>>>>>>>>>>
n = 8
mc= lambda x,n: sum(((-1)**i) * (x ** (2*i)) / (math.factorial(2 * i)) for i in range(n+1))
#<<<<<<<<<<<<<<<<<<<<<<<<<


#Creating a vector of 100 various values of x
#between -20 and +20 to help us plot our function.
x = np.linspace(-20,+20,100)


for i in range(n+1): #Implementing Sigma (sum) function.

  #Plotting Configuration
  plt.rcParams['figure.figsize'] = [6.0, 3.0]
  plt.rcParams['figure.dpi'] = 80
  plt.plot(x,mc(x,i) , color = 'red')
  plt.plot(x,np.cos(x) , color = 'blue')
  plt.xlim((-6,6))
  plt.ylim((-3,3))
  plt.xlabel("Maclaurin Series up to $f_{0}(x)$".format(i))
  plt.title("Assessment: 2.1")
  plt.grid(visible=True)
  plt.show()

# %% [markdown]
# * The function $f(x) = e^x$ is absolutely well-behaved and continuos everywhere. Its Maclaurin Series can be calculated as follows:
# <br>
#
# $$ f_n(x) =1 + x + \frac{x^2}{2!}+\frac{x^3}{3!} ....$$
# <br>
#
# $$ f_n(x) =\sum \limits _{i=0} ^{n}\frac{x^{n}}{n!}$$ <br>
#
# * And the corresponding Taylor Series at the point $p$ can also be calculated in a similar way as follows:<br><br>
#
# $$ f_n(x) =\sum \limits _{i=0} ^{n}\frac{e^p(x-p)^{n}}{n!}$$
# <br>
# <br>
# $$ f_n(x) =\frac{e^p}{1}+\frac{e^p (x-p)}{1}+\frac{e^p (x-p)^2}{2} ....$$

# %%
# Importing required libraries
import numpy as np
import matplotlib.pyplot as plt
import math

# Maclaurin series definition for f(x) = e^x
#>>>>>>>>>>>>>>>>>>>>>>>>>
n = 8
mc= lambda x,n: sum((x**i)/(np.math.factorial(i)) for i in range(n+1))
#<<<<<<<<<<<<<<<<<<<<<<<<<


#Creating a vector of 100 various values of x
#between -20 and +20 to help us plot our function.
x = np.linspace(-20,+20,100)


for i in range(n): #Implementing Sigma (sum) function.
  pdf = mc(x,i)

  #Plotting Configuration
  plt.rcParams['figure.figsize'] = [6.0, 3.0]
  plt.rcParams['figure.dpi'] = 80
  plt.plot(x,pdf , color = 'red')
  plt.plot(x,np.math.e**x , color = 'blue')
  plt.xlim((-6,6))
  plt.ylim((-3,3))
  plt.xlabel("Maclaurin Series up to $f_{0}(x)$".format(i))
  plt.title("Assessment: 2.2")
  plt.grid(visible=True)
  plt.show()

# %%
# Importing required libraries
import numpy as np
import matplotlib.pyplot as plt
import math

# Taylor series definition for f(x) = e^x at the point p = -2
#>>>>>>>>>>>>>>>>>>>>>>>>>
n = 8
p = -2
ts= lambda x,n: sum(((np.math.e**p)*(x-p)**i)/(np.math.factorial(i)) for i in range(n+1))
#<<<<<<<<<<<<<<<<<<<<<<<<<


#Creating a vector of 100 various values of x
#between -20 and +20 to help us plot our function.
x = np.linspace(-20,+20,100)


for i in range(n): #Implementing Sigma (sum) function.

  #Plotting Configuration
  plt.rcParams['figure.figsize'] = [6.0, 3.0]
  plt.rcParams['figure.dpi'] = 80
  plt.plot(x,ts(x,i) , color = 'red')
  plt.plot(x,np.math.e**x , color = 'blue')
  plt.xlim((-6,6))
  plt.ylim((-3,3))
  plt.xlabel("Taylor Series up to $f_{0}(x)$ at the point $p={1}$".format(i,p))
  plt.title("Assessment: 2.2")
  plt.grid(visible=True)
  plt.show()

# %% [markdown]
# -------------------
# ##### *For the **multivariable fuction**$ f(x,y) = e^{-(x^2-y^2)}$, the second-degree Taylor polynomial at the point (a,b) is:*
# <br>
# $$ Talor Series Formula : f_2(x+a,y+b) =f(a,b)+\partial f(a,b) \begin{bmatrix}
# x-a\\y-b\end{bmatrix}+\frac{1}{2}\begin{bmatrix}
# x-a & y-b\end{bmatrix}Hf(a,b)\begin{bmatrix}
# x-a\\y-b\end{bmatrix}$$
#
# <br>
# For $a,b = 0$ we have:
# $$ f_2(x,y) = 1- x^2 - y^2$$
#
# <br>

# %%
# Importing required libraries
import numpy as np
import matplotlib.pyplot as plt

# Taylor series definition for f(x,y) = 𝑒^−(𝑥2−𝑦2)
#>>>>>>>>>>>>>>>>>>>>>>>>>
z = lambda x,y: np.e**(-(x**2+y**2))
mc = lambda x,y: 1 - x**2 - y**2
#<<<<<<<<<<<<<<<<<<<<<<<<<

# defining surface and axes
x = np.outer(np.linspace(-2, 2, 10), np.ones(10))
y = x.copy().T

#Plotting Configuration
fig = plt.figure()
ax = plt.axes(projection='3d')
ax.plot_surface(x, y, z(x,y), cmap='viridis',edgecolor='green')
ax.plot_surface(x, y, mc(x,y), cmap='viridis',edgecolor='green')
ax.set_title('Assessment: 2.3')
plt.rcParams['figure.figsize'] = [10, 5]
plt.rcParams['figure.dpi'] = 100
plt.show()

# %% [markdown]
# ### You have done a real work so far. It's time to rest for a while to get ready for the next module.
#
# # SEE YOU THEN.... :)
